# %% [markdown]
# # Challenge Part 1: Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import requests
from datetime import datetime

from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=905b32babdb8b30c96f3b85b5e463ca8

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f'{url}&q={city.replace(" ","+")}'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ancud
# Processing Record 2 of Set 1 | coihaique
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | kirovo-chepetsk
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | rabaul
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | mahanoro
# Processing Record 14 of Set 1 | yibin
# Processing Record 15 of Set 1 | martin
# Processing Record 16 of Set 1 | isangel
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | mandal
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | ostrovnoy
# Processing Record 24 of Set 1 | awjilah
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | vidim
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | krasnoselkup
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | nenjiang
# Processing Record 31 of Set 1 | luena
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | shaoxing
# Processing Record 34 of Set 1 | bonfim
# Processing Record 35 of Set 1 | brae
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | creel
# Processing Record 38 of Set 1 | nikolayevsk-na-amure
# Processing Record 39 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | neiafu
# Processing Record 44 of Set 1 | fredericksburg
# Processing Record 45 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 1 | joshimath
# Processing Record 47 of Set 1 | dunedin
# Processing Record 48 of Set 1 | woodward
# Processing Record 49 of Set 1 | oriximina
# Processing Record 50 of Set 1 | nouakchott
# Processing Record 1 of Set 2 | murray bridge
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | pasighat
# Processing Record 4 of Set 2 | chiredzi
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | olafsvik
# Processing Record 7 of Set 2 | santa cruz del norte
# Processing Record 8 of Set 2 | ayorou
# Processing Record 9 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | lata
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | poya
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | nibbar
# Processing Record 20 of Set 2 | abonnema
# Processing Record 21 of Set 2 | chara
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | hamilton
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | kidal
# Processing Record 31 of Set 2 | omboue
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | gizo
# Processing Record 34 of Set 2 | hoyerswerda
# Processing Record 35 of Set 2 | sao felix do xingu
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | beringovskiy
# Processing Record 44 of Set 2 | karratha
# Processing Record 45 of Set 2 | sinnamary
# Processing Record 46 of Set 2 | tadine
# Processing Record 47 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | ekhabi
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | luau
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | pitimbu
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | hastings
# Processing Record 8 of Set 3 | tehachapi
# Processing Record 9 of Set 3 | talcahuano
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | oyama
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | sandata
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | port blair
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | maubin
# Processing Record 24 of Set 3 | champerico
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | otavi
# Processing Record 27 of Set 3 | bonavista
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 3 | palu
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | bud
# Processing Record 33 of Set 3 | karpathos
# Processing Record 34 of Set 3 | lang son
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | miramar
# Processing Record 37 of Set 3 | canberra
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | alyangula
# Processing Record 45 of Set 3 | bonham
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | karlskrona
# Processing Record 48 of Set 3 | pyaozerskiy
# Processing Record 49 of Set 3 | miri
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | rafaela
# Processing Record 2 of Set 4 | ossora
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | korla
# Processing Record 5 of Set 4 | moussoro
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | akdagmadeni
# Processing Record 8 of Set 4 | san policarpo
# Processing Record 9 of Set 4 | shashi
# Processing Record 10 of Set 4 | inuvik
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | solwezi
# Processing Record 13 of Set 4 | pachino
# Processing Record 14 of Set 4 | bilibino
# Processing Record 15 of Set 4 | lalibela
# Processing Record 16 of Set 4 | taybad
# Processing Record 17 of Set 4 | hami
# Processing Record 18 of Set 4 | labrea
# Processing Record 19 of Set 4 | dharchula
# Processing Record 20 of Set 4 | dhidhdhoo
# Processing Record 21 of Set 4 | gayny
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | mehamn
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | komsomolskiy
# Processing Record 26 of Set 4 | atka
# City not found. Skipping...
# Processing Record 27 of Set 4 | whitehorse
# Processing Record 28 of Set 4 | sassandra
# Processing Record 29 of Set 4 | yangambi
# Processing Record 30 of Set 4 | bucerias
# Processing Record 31 of Set 4 | sahuaripa
# Processing Record 32 of Set 4 | oktyabrskoye
# Processing Record 33 of Set 4 | marsa matruh
# Processing Record 34 of Set 4 | sola
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | lima
# Processing Record 37 of Set 4 | fort frances
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | rorvik
# Processing Record 42 of Set 4 | pasni
# Processing Record 43 of Set 4 | glan padidu
# Processing Record 44 of Set 4 | santa cruz
# Processing Record 45 of Set 4 | carolina
# Processing Record 46 of Set 4 | formosa do rio preto
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | bingol
# Processing Record 50 of Set 4 | yeovil
# Processing Record 1 of Set 5 | trelew
# Processing Record 2 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | nakhon phanom
# Processing Record 5 of Set 5 | loukhi
# Processing Record 6 of Set 5 | tommot
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | sorong
# Processing Record 10 of Set 5 | ipora
# Processing Record 11 of Set 5 | kapaa
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | dikson
# Processing Record 14 of Set 5 | tabasco
# Processing Record 15 of Set 5 | kruisfontein
# Processing Record 16 of Set 5 | sehwan
# Processing Record 17 of Set 5 | vestmannaeyjar
# Processing Record 18 of Set 5 | nantucket
# Processing Record 19 of Set 5 | ikungi
# Processing Record 20 of Set 5 | dibrugarh
# Processing Record 21 of Set 5 | bosaso
# Processing Record 22 of Set 5 | chany
# Processing Record 23 of Set 5 | rayagada
# Processing Record 24 of Set 5 | paamiut
# Processing Record 25 of Set 5 | antalaha
# Processing Record 26 of Set 5 | tsuruoka
# Processing Record 27 of Set 5 | lasa
# Processing Record 28 of Set 5 | san matias
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 5 | dudinka
# Processing Record 32 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | melur
# Processing Record 36 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 5 | iracoubo
# Processing Record 38 of Set 5 | atsiki
# City not found. Skipping...
# Processing Record 39 of Set 5 | road town
# Processing Record 40 of Set 5 | shanghai
# Processing Record 41 of Set 5 | sao filipe
# Processing Record 42 of Set 5 | cherat
# Processing Record 43 of Set 5 | andapa
# Processing Record 44 of Set 5 | nome
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | belyy yar
# Processing Record 47 of Set 5 | siuna
# Processing Record 48 of Set 5 | teguldet
# Processing Record 49 of Set 5 | waipawa
# Processing Record 50 of Set 5 | lazaro cardenas
# Processing Record 1 of Set 6 | cabo san lucas
# Processing Record 2 of Set 6 | kamaishi
# Processing Record 3 of Set 6 | zambezi
# Processing Record 4 of Set 6 | novobirilyussy
# Processing Record 5 of Set 6 | barcelos
# Processing Record 6 of Set 6 | saint-georges
# Processing Record 7 of Set 6 | chapais
# Processing Record 8 of Set 6 | toora-khem
# Processing Record 9 of Set 6 | naze
# Processing Record 10 of Set 6 | tres arroyos
# Processing Record 11 of Set 6 | lompoc
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | trairi
# Processing Record 15 of Set 6 | palmas
# Processing Record 16 of Set 6 | morehead
# Processing Record 17 of Set 6 | vung tau
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | dong hoi
# Processing Record 21 of Set 6 | zyryanka
# Processing Record 22 of Set 6 | ola
# Processing Record 23 of Set 6 | mitsamiouli
# Processing Record 24 of Set 6 | sept-iles
# Processing Record 25 of Set 6 | mabaruma
# Processing Record 26 of Set 6 | seddon
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | chicama
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | chaiya
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | that phanom
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | mandera
# Processing Record 36 of Set 6 | kochubey
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | kendari
# Processing Record 39 of Set 6 | berdigestyakh
# Processing Record 40 of Set 6 | topolobampo
# Processing Record 41 of Set 6 | milkovo
# Processing Record 42 of Set 6 | saskylakh
# Processing Record 43 of Set 6 | xinyang
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | kloulklubed
# Processing Record 46 of Set 6 | okhotsk
# Processing Record 47 of Set 6 | sheopur
# Processing Record 48 of Set 6 | duki
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | nara
# Processing Record 1 of Set 7 | kalemie
# Processing Record 2 of Set 7 | iqaluit
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | santa luzia
# Processing Record 5 of Set 7 | abu kamal
# Processing Record 6 of Set 7 | bata
# Processing Record 7 of Set 7 | katsuura
# Processing Record 8 of Set 7 | gat
# Processing Record 9 of Set 7 | axim
# Processing Record 10 of Set 7 | flin flon
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | fougamou
# Processing Record 13 of Set 7 | guebwiller
# Processing Record 14 of Set 7 | blagoveshchensk
# Processing Record 15 of Set 7 | dzaoudzi
# Processing Record 16 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 7 | kununurra
# Processing Record 18 of Set 7 | kisangani
# Processing Record 19 of Set 7 | victor harbor
# Processing Record 20 of Set 7 | kozhva
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | escuintla
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | mecca
# Processing Record 25 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 7 | havelock
# Processing Record 28 of Set 7 | kavaratti
# Processing Record 29 of Set 7 | thinadhoo
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | kaitong
# Processing Record 32 of Set 7 | saint-pierre
# Processing Record 33 of Set 7 | valparaiso
# Processing Record 34 of Set 7 | santa maria
# Processing Record 35 of Set 7 | nueva loja
# Processing Record 36 of Set 7 | lagoa
# Processing Record 37 of Set 7 | talavera de la reina
# Processing Record 38 of Set 7 | bathsheba
# Processing Record 39 of Set 7 | bonthe
# Processing Record 40 of Set 7 | phan thiet
# Processing Record 41 of Set 7 | nishihara
# Processing Record 42 of Set 7 | itamaraju
# Processing Record 43 of Set 7 | aitape
# Processing Record 44 of Set 7 | auki
# Processing Record 45 of Set 7 | lulea
# Processing Record 46 of Set 7 | beyneu
# Processing Record 47 of Set 7 | santiago de cao
# Processing Record 48 of Set 7 | tiksi
# Processing Record 49 of Set 7 | finschhafen
# Processing Record 50 of Set 7 | ahipara
# Processing Record 1 of Set 8 | trofors
# Processing Record 2 of Set 8 | ouricuri
# Processing Record 3 of Set 8 | bangad
# Processing Record 4 of Set 8 | tazmalt
# Processing Record 5 of Set 8 | indramayu
# Processing Record 6 of Set 8 | camopi
# Processing Record 7 of Set 8 | hede
# Processing Record 8 of Set 8 | kijang
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | ariquemes
# Processing Record 11 of Set 8 | seymchan
# Processing Record 12 of Set 8 | xucheng
# Processing Record 13 of Set 8 | north bend
# Processing Record 14 of Set 8 | skibotn
# Processing Record 15 of Set 8 | japura
# Processing Record 16 of Set 8 | linjiang
# Processing Record 17 of Set 8 | puerto leguizamo
# Processing Record 18 of Set 8 | maniitsoq
# Processing Record 19 of Set 8 | viedma
# Processing Record 20 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 21 of Set 8 | buala
# Processing Record 22 of Set 8 | eydhafushi
# Processing Record 23 of Set 8 | hirara
# Processing Record 24 of Set 8 | cabra
# Processing Record 25 of Set 8 | bansgaon
# Processing Record 26 of Set 8 | hobyo
# Processing Record 27 of Set 8 | perth
# Processing Record 28 of Set 8 | bang yai
# Processing Record 29 of Set 8 | omsukchan
# Processing Record 30 of Set 8 | nizhniy lomov
# Processing Record 31 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 8 | dzhebariki-khaya
# Processing Record 33 of Set 8 | atar
# Processing Record 34 of Set 8 | bontang
# Processing Record 35 of Set 8 | mandaguacu
# Processing Record 36 of Set 8 | goma
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | ilulissat
# Processing Record 39 of Set 8 | asau
# Processing Record 40 of Set 8 | nhulunbuy
# Processing Record 41 of Set 8 | maldonado
# Processing Record 42 of Set 8 | mayo
# Processing Record 43 of Set 8 | dalby
# Processing Record 44 of Set 8 | magay
# Processing Record 45 of Set 8 | san patricio
# Processing Record 46 of Set 8 | uk
# City not found. Skipping...
# Processing Record 47 of Set 8 | tskaltubo
# Processing Record 48 of Set 8 | baoning
# Processing Record 49 of Set 8 | catuday
# Processing Record 50 of Set 8 | nouadhibou
# Processing Record 1 of Set 9 | dahuk
# Processing Record 2 of Set 9 | pitanga
# Processing Record 3 of Set 9 | sorland
# Processing Record 4 of Set 9 | praia
# Processing Record 5 of Set 9 | pochutla
# Processing Record 6 of Set 9 | phulpur
# Processing Record 7 of Set 9 | zvishavane
# Processing Record 8 of Set 9 | tukrah
# Processing Record 9 of Set 9 | toungoo
# City not found. Skipping...
# Processing Record 10 of Set 9 | horadiz
# Processing Record 11 of Set 9 | lorengau
# Processing Record 12 of Set 9 | borogontsy
# Processing Record 13 of Set 9 | gerash
# Processing Record 14 of Set 9 | nabire
# Processing Record 15 of Set 9 | jumla
# Processing Record 16 of Set 9 | sur
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | silveira
# Processing Record 19 of Set 9 | eyrarbakki
# Processing Record 20 of Set 9 | tutoia
# Processing Record 21 of Set 9 | yanggu
# Processing Record 22 of Set 9 | roma
# Processing Record 23 of Set 9 | ngunguru
# Processing Record 24 of Set 9 | sarangani
# Processing Record 25 of Set 9 | kahului
# Processing Record 26 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 9 | jacareacanga
# Processing Record 28 of Set 9 | vila franca do campo
# Processing Record 29 of Set 9 | pevek
# Processing Record 30 of Set 9 | mount isa
# Processing Record 31 of Set 9 | derzhavinsk
# Processing Record 32 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 33 of Set 9 | male
# Processing Record 34 of Set 9 | ntungamo
# Processing Record 35 of Set 9 | libreville
# Processing Record 36 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 9 | arlit
# Processing Record 38 of Set 9 | berbera
# Processing Record 39 of Set 9 | balkanabat
# Processing Record 40 of Set 9 | kutum
# Processing Record 41 of Set 9 | cayenne
# Processing Record 42 of Set 9 | saint-francois
# Processing Record 43 of Set 9 | yarada
# Processing Record 44 of Set 9 | dodoma
# Processing Record 45 of Set 9 | venice
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | tual
# Processing Record 48 of Set 9 | hilo
# Processing Record 49 of Set 9 | havre-saint-pierre
# Processing Record 50 of Set 9 | kotaparh
# Processing Record 1 of Set 10 | hervey bay
# Processing Record 2 of Set 10 | ponta do sol
# Processing Record 3 of Set 10 | tessalit
# Processing Record 4 of Set 10 | foam lake
# Processing Record 5 of Set 10 | itoman
# Processing Record 6 of Set 10 | tucuma
# Processing Record 7 of Set 10 | khasan
# Processing Record 8 of Set 10 | abapo
# Processing Record 9 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 10 | ukiah
# Processing Record 11 of Set 10 | russell
# Processing Record 12 of Set 10 | sistranda
# Processing Record 13 of Set 10 | novyy urengoy
# Processing Record 14 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 15 of Set 10 | nanakuli
# Processing Record 16 of Set 10 | torbay
# Processing Record 17 of Set 10 | sisimiut
# Processing Record 18 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 19 of Set 10 | qasigiannguit
# Processing Record 20 of Set 10 | flinders
# Processing Record 21 of Set 10 | rodrigues alves
# Processing Record 22 of Set 10 | floro
# Processing Record 23 of Set 10 | bubaque
# Processing Record 24 of Set 10 | zheleznodorozhnyy
# Processing Record 25 of Set 10 | polewali
# Processing Record 26 of Set 10 | zatoka
# Processing Record 27 of Set 10 | nizhniy kuranakh
# Processing Record 28 of Set 10 | constitucion
# Processing Record 29 of Set 10 | yar-sale
# Processing Record 30 of Set 10 | honiara
# Processing Record 31 of Set 10 | ucluelet
# Processing Record 32 of Set 10 | de aar
# Processing Record 33 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 10 | baykit
# Processing Record 35 of Set 10 | kamenka
# Processing Record 36 of Set 10 | laguna
# Processing Record 37 of Set 10 | olinda
# Processing Record 38 of Set 10 | balakovo
# Processing Record 39 of Set 10 | port hawkesbury
# Processing Record 40 of Set 10 | bairiki
# Processing Record 41 of Set 10 | zhangye
# Processing Record 42 of Set 10 | gumdag
# Processing Record 43 of Set 10 | nuuk
# Processing Record 44 of Set 10 | laksham
# Processing Record 45 of Set 10 | akom
# Processing Record 46 of Set 10 | dingle
# Processing Record 47 of Set 10 | nybro
# Processing Record 48 of Set 10 | vrangel
# Processing Record 49 of Set 10 | batagay-alyta
# Processing Record 50 of Set 10 | natal
# Processing Record 1 of Set 11 | zhigansk
# Processing Record 2 of Set 11 | posse
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | lokosovo
# Processing Record 5 of Set 11 | marolambo
# Processing Record 6 of Set 11 | kieta
# Processing Record 7 of Set 11 | sijunjung
# Processing Record 8 of Set 11 | tomari
# Processing Record 9 of Set 11 | macherla
# Processing Record 10 of Set 11 | huangmei
# Processing Record 11 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 11 | ninghai
# Processing Record 14 of Set 11 | santa cecilia
# Processing Record 15 of Set 11 | leon
# Processing Record 16 of Set 11 | uruzgan
# Processing Record 17 of Set 11 | vangaindrano
# Processing Record 18 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 11 | khandbari
# Processing Record 20 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 21 of Set 11 | seoul
# Processing Record 22 of Set 11 | tucuman
# Processing Record 23 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 11 | skelleftea
# Processing Record 25 of Set 11 | zaranj
# Processing Record 26 of Set 11 | buba
# Processing Record 27 of Set 11 | rocha
# Processing Record 28 of Set 11 | gimbi
# Processing Record 29 of Set 11 | san cristobal
# Processing Record 30 of Set 11 | ulladulla
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 11 | guerrero negro
# Processing Record 34 of Set 11 | mackay
# Processing Record 35 of Set 11 | marystown
# Processing Record 36 of Set 11 | klyuchi
# Processing Record 37 of Set 11 | pacific grove
# Processing Record 38 of Set 11 | roela
# Processing Record 39 of Set 11 | ilhabela
# Processing Record 40 of Set 11 | rio cuarto
# Processing Record 41 of Set 11 | the valley
# Processing Record 42 of Set 11 | nizwa
# Processing Record 43 of Set 11 | asmara
# Processing Record 44 of Set 11 | nizhniy tsasuchey
# Processing Record 45 of Set 11 | aykhal
# Processing Record 46 of Set 11 | smithers
# Processing Record 47 of Set 11 | namatanai
# Processing Record 48 of Set 11 | corbu
# Processing Record 49 of Set 11 | ouadda
# Processing Record 50 of Set 11 | jamtara
# Processing Record 1 of Set 12 | sangre grande
# Processing Record 2 of Set 12 | borgosesia
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 12 | krapivinskiy
# Processing Record 5 of Set 12 | kautokeino
# Processing Record 6 of Set 12 | serowe
# Processing Record 7 of Set 12 | haines junction
# Processing Record 8 of Set 12 | eyl
# Processing Record 9 of Set 12 | ayr
# Processing Record 10 of Set 12 | launceston
# Processing Record 11 of Set 12 | maulvi bazar
# City not found. Skipping...
# Processing Record 12 of Set 12 | lucea
# Processing Record 13 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 12 | goundi
# Processing Record 15 of Set 12 | karasjok
# Processing Record 16 of Set 12 | clarence town
# Processing Record 17 of Set 12 | talaya
# Processing Record 18 of Set 12 | mount gambier
# Processing Record 19 of Set 12 | tonj
# Processing Record 20 of Set 12 | coruripe
# Processing Record 21 of Set 12 | galle
# Processing Record 22 of Set 12 | sibu
# Processing Record 23 of Set 12 | chumikan
# Processing Record 24 of Set 12 | rio gallegos
# Processing Record 25 of Set 12 | vardo
# Processing Record 26 of Set 12 | krasnyy kut
# Processing Record 27 of Set 12 | mangrol
# Processing Record 28 of Set 12 | wagar
# Processing Record 29 of Set 12 | keshod
# Processing Record 30 of Set 12 | bungu
# Processing Record 31 of Set 12 | beloha
# Processing Record 32 of Set 12 | lysva
# Processing Record 33 of Set 12 | soe
# Processing Record 34 of Set 12 | hun
# Processing Record 35 of Set 12 | zhangjiakou
# Processing Record 36 of Set 12 | tateyama
# Processing Record 37 of Set 12 | sayyan
# Processing Record 38 of Set 12 | wanning
# Processing Record 39 of Set 12 | porto novo
# Processing Record 40 of Set 12 | porto santo
# Processing Record 41 of Set 12 | coronado
# Processing Record 42 of Set 12 | arman
# Processing Record 43 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | larsnes
# Processing Record 45 of Set 12 | tingo maria
# Processing Record 46 of Set 12 | kigoma
# Processing Record 47 of Set 12 | sinegorsk
# Processing Record 48 of Set 12 | muravlenko
# Processing Record 49 of Set 12 | kaeo
# Processing Record 50 of Set 12 | jiaojiang
# Processing Record 1 of Set 13 | codrington
# Processing Record 2 of Set 13 | kargil
# Processing Record 3 of Set 13 | izazi
# Processing Record 4 of Set 13 | xinqing
# Processing Record 5 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 13 | urumqi
# Processing Record 7 of Set 13 | souillac
# Processing Record 8 of Set 13 | alice springs
# Processing Record 9 of Set 13 | bahar
# Processing Record 10 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 13 | yuryevets
# Processing Record 12 of Set 13 | iskateley
# Processing Record 13 of Set 13 | jingdezhen
# Processing Record 14 of Set 13 | elmira
# Processing Record 15 of Set 13 | praia da vitoria
# Processing Record 16 of Set 13 | kiruna
# Processing Record 17 of Set 13 | andenes
# Processing Record 18 of Set 13 | mazamari
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | tongzhou
# Processing Record 21 of Set 13 | nogliki
# Processing Record 22 of Set 13 | luanda
# Processing Record 23 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 24 of Set 13 | kondinskoye
# Processing Record 25 of Set 13 | gazli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City    Lat     Lng  Max Temp Current Description  \
# 0              Ancud -41.87  -73.82     55.99       broken clouds
# 1          Coihaique -45.58  -72.07     50.00    scattered clouds
# 2              Vaini -21.20 -175.20     69.80          few clouds
# 3    Kirovo-Chepetsk  58.55   50.04     51.71           clear sky
# 4               Lebu -37.62  -73.65     52.27       moderate rain
# ..               ...    ...     ...       ...                 ...
# 570         Tongzhou  39.91  116.60     79.00     overcast clouds
# 571          Nogliki  51.83  143.17     40.48     overcast clouds
# 572           Luanda  -8.84   13.23     75.20    scattered clouds
# 573      Kondinskoye  59.65   67.41     45.34     overcast clouds
# 574            Gazli  40.13   63.45     79.30           clear sky
#
#      Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0             0.00              0        87          75       11.41      CL
# 1             0.00              0        66          40        4.70      CL
# 2             0.00              0        83          20        8.05      TO
# 3             0.00              0        68           0        1.99      RU
# 4             3.23              0        94         100       14.47      CL
# ..             ...            ...       ...         ...         ...     ...
# 570           0.00              0        73          90        6.71      CN
# 571           0.00              0        97         100       10.11      RU
# 572           0.00              0        78          36        8.05      AO
# 573           0.00              0        60          93        7.94      RU
# 574           0.00              0        16           6        9.42      UZ
#
# [575 rows x 11 columns]

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City  Cloudiness Country Current Description  Humidity    Lat  \
# 0            Ancud          75      CL       broken clouds        87 -41.87
# 1        Coihaique          40      CL    scattered clouds        66 -45.58
# 2            Vaini          20      TO          few clouds        83 -21.20
# 3  Kirovo-Chepetsk           0      RU           clear sky        68  58.55
# 4             Lebu         100      CL       moderate rain        94 -37.62
# 5           Albany           4      US           clear sky        52  42.60
# 6        Geraldton          10      AU           clear sky        87 -28.77
# 7     Norman Wells          75      CA       broken clouds        49  65.28
# 8        Upernavik           0      GL           clear sky        82  72.79
# 9           Rabaul          20      PG          few clouds        78  -4.20
#
#       Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0  -73.82     55.99           0.00              0       11.41
# 1  -72.07     50.00           0.00              0        4.70
# 2 -175.20     69.80           0.00              0        8.05
# 3   50.04     51.71           0.00              0        1.99
# 4  -73.65     52.27           3.23              0       14.47
# 5  -73.97     84.99           0.00              0        5.93
# 6  114.60     50.00           0.00              0        4.70
# 7 -126.83     71.60           0.00              0       10.29
# 8  -56.15     36.12           0.00              0        9.89
# 9  152.17     80.56           0.00              0        9.13

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)            int64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities
# Out:
#            City  Cloudiness Country Current Description  Humidity    Lat  \
# 4          Lebu         100      CL       moderate rain        94 -37.62
# 11     Mahanoro          15      MG          light rain        85 -19.90
# 18      Rikitea          93      PF          light rain        84 -23.12
# 23       Atuona          38      PF          light rain        78  -9.80
# 32       Bonfim          62      BR          light rain        72   3.08
# ..          ...         ...     ...                 ...       ...    ...
# 523    Coruripe          18      BR          light rain        81 -10.13
# 539    Tateyama         100      JP          light rain        99  34.98
# 541     Wanning           2      CN          light rain        89  18.80
# 552   Jiaojiang          99      CN          light rain        95  28.68
# 563  Jingdezhen          96      CN          light rain        95  29.29
#
#         Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 4    -73.65     52.27           3.23              0       14.47
# 11    48.80     66.88           0.40              0        6.71
# 18  -134.97     76.19           0.37              0       16.71
# 23  -139.03     79.48           0.22              0       12.06
# 32   -59.95     84.42           0.33              0        6.87
# ..      ...       ...            ...            ...         ...
# 523  -36.18     79.12           0.46              0       14.72
# 539  139.87     68.00           0.58              0        7.74
# 541  110.40     81.55           0.13              0        9.95
# 552  121.44     73.99           0.56              0        1.01
# 563  117.21     71.62           0.31              0        2.42
#
# [73 rows x 11 columns]

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Current Description, Humidity, Lat, Lng, Max Temp, Rain (inches), Snow (inches), Wind Speed]
# Index: []

# %%
# Create output file (CSV)
output_data_file = "data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
